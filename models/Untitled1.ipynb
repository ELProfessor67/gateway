# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import LinearSVC
from sklearn.pipeline import Pipeline
import json

# %%
with open('questions.json', 'r') as f:
    data = json.load(f)

# %%
questions = [item['question'] for item in data]
answers = [item['answer'] for item in data]

# %%
# Vectorize text data
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(questions)

# Train classifier
classifier = LinearSVC()
classifier.fit(X, questions)
# Out:
# C:\Users\user\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\svm\_classes.py:32: FutureWarning: The default value of `dual` will change from `True` to `'auto'` in 1.5. Set the value of `dual` explicitly to suppress the warning.
#   warnings.warn(
# LinearSVC()

# %%
def get_answer(question):
    question_vec = vectorizer.transform([question])
    predicted_question = classifier.predict(question_vec)[0]
    
    for item in data:
        if item['question'] == predicted_question:
            return item['answer']
    
    return "Sorry, I don't have an answer for that question."

# %%
answer = get_answer("Why Our System is Secure ?")

# %%
answer
# Out:
# 'All data is encrypted using end-to-end encryption to ensure maximum security.'
